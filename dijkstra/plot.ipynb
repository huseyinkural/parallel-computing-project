# %%
import matplotlib.pyplot as plt

gpu_times = []
cpu_times = []
sizes = []

with open('dijkstra_results.log', 'r') as file:
    for line in file:
        parts = line.split(' ')
        time = float(parts[4])
        size = int(parts[8])
        
        if 'GPU' in line:
            gpu_times.append(time)
        elif 'CPU' in line:
            cpu_times.append(time)
        
        sizes.append(size)

gpu_sizes = sizes[::2]
cpu_sizes = sizes[1::2]  

plt.figure(figsize=(10, 6))

plt.plot(gpu_sizes, gpu_times, marker='o', label='Dijkstra GPU', color='red')
plt.plot(cpu_sizes, cpu_times, marker='o', label='Dijkstra CPU', color = 'blue')

plt.title('DIJKSTRA GPU CUDA X CPU KARŞILAŞTIRMASI')
plt.xlabel('Matrix Boyutu')
plt.ylabel('Çalışma Süresi (saniye)')
plt.legend()
plt.grid(True)
plt.show()
